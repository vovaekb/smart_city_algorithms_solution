# %%
import requests 
import json
import time
import os
import pandas as pd
from sqlalchemy import engine as sql
from IPython import display
import ipywidgets as widget
import matplotlib.pyplot as plt
import math

# %%
data = requests.get('https://api.hh.ru/vacancies?text=java').json()
data
# Out:
# {'items': [{'id': '44706219',
#    'premium': False,
#    'name': 'Junior Java Developer',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 90000, 'to': 140000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-06-12T11:39:02+0300',
#    'created_at': '2021-06-12T11:39:02+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=44706219',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/44706219?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/44706219',
#    'relations': [],
#    'employer': {'id': '193245',
#     'name': 'INTECH',
#     'url': 'https://api.hh.ru/employers/193245',
#     'alternate_url': 'https://hh.ru/employer/193245',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/245726.png',
#      '90': 'https://hhcdn.ru/employer-logo/1425577.png',
#      '240': 'https://hhcdn.ru/employer-logo/1425578.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=193245',
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт коммерческой разработки не менее 6 месяцев. <highlighttext>Java</highlighttext> core ООП: работаю по SOLID, применяю базовые паттерны. <highlighttext>Java</highlighttext> collection: знаю базовые...',
#     'responsibility': 'Разрабатывать компоненты и системы для новых проектов. Сопровождать существующие продукты (докручиваем новые фичи, обновляем версии сервисов и т.д.). '},
#    'contacts': None,
#    'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '45362662',
#    'premium': False,
#    'name': 'Java-разработчик',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '2',
#     'name': 'Санкт-Петербург',
#     'url': 'https://api.hh.ru/areas/2'},
#    'salary': {'from': 210000, 'to': 350000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-06-10T09:44:52+0300',
#    'created_at': '2021-06-10T09:44:52+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=45362662',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/45362662?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/45362662',
#    'relations': [],
#    'employer': {'id': '5438907',
#     'name': 'Романова Алина Александровна',
#     'url': 'https://api.hh.ru/employers/5438907',
#     'alternate_url': 'https://hh.ru/employer/5438907',
#     'logo_urls': None,
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=5438907',
#     'trusted': False},
#    'snippet': {'requirement': 'Привносить новые технологии и практики. - Пишешь на <highlighttext>Java</highlighttext> более 3-х лет. - Дружишь с <highlighttext>Java</highlighttext> Core и <highlighttext>Java</highlighttext> SE. - ',
#     'responsibility': 'Поддерживать работающую систему, обслуживающую большое количество клиентов. - Разрабатывать и создавать новые модули. - Оптимизировать существующие решения функционала и развивать их. - '},
#    'contacts': None,
#    'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '45187916',
#    'premium': False,
#    'name': 'Java - разработчик (стажер)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '68', 'name': 'Омск', 'url': 'https://api.hh.ru/areas/68'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Омск',
#     'street': 'Ильинская улица',
#     'building': '4',
#     'description': None,
#     'lat': 54.979878,
#     'lng': 73.374437,
#     'raw': 'Омск, Ильинская улица, 4',
#     'metro': None,
#     'metro_stations': [],
#     'id': '906841'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-06-12T14:48:58+0300',
#    'created_at': '2021-06-12T14:48:58+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=45187916',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/45187916?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/45187916',
#    'relations': [],
#    'employer': {'id': '231783',
#     'name': 'AIM Consulting',
#     'url': 'https://api.hh.ru/employers/231783',
#     'alternate_url': 'https://hh.ru/employer/231783',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3836764.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3836763.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/848972.jpg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=231783',
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт прохождения стажировок/школ/курсов в ИТ- компаниях или онлайн по направлению <highlighttext>Java</highlighttext>. Базовые знания <highlighttext>Java</highlighttext>. Базовые знания SQL. ',
#     'responsibility': 'Выполнение тестового задания. Собеседование с ментором по итогам задания и в целом.'},
#    'contacts': None,
#    'schedule': {'id': 'flexible', 'name': 'Гибкий график'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '45395360',
#    'premium': False,
#    'name': 'Junior Java-разработчик',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Саввинская набережная',
#     'building': '15',
#     'description': None,
#     'lat': 55.734866,
#     'lng': 37.566189,
#     'raw': 'Москва, Саввинская набережная, 15',
#     'metro': {'station_name': 'Киевская',
#      'line_name': 'Арбатско-Покровская',
#      'station_id': '3.47',
#      'line_id': '3',
#      'lat': 55.743117,
#      'lng': 37.564132},
#     'metro_stations': [{'station_name': 'Киевская',
#       'line_name': 'Арбатско-Покровская',
#       'station_id': '3.47',
#       'line_id': '3',
#       'lat': 55.743117,
#       'lng': 37.564132},
#      {'station_name': 'Киевская',
#       'line_name': 'Филевская',
#       'station_id': '4.48',
#       'line_id': '4',
#       'lat': 55.743168,
#       'lng': 37.565425},
#      {'station_name': 'Киевская',
#       'line_name': 'Кольцевая',
#       'station_id': '5.49',
#       'line_id': '5',
#       'lat': 55.74361,
#       'lng': 37.56735}],
#     'id': '730401'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-06-11T10:27:48+0300',
#    'created_at': '2021-06-11T10:27:48+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=45395360',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/45395360?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/45395360',
#    'relations': [],
#    'employer': {'id': '63198',
#     'name': 'Gridnine Systems',
#     'url': 'https://api.hh.ru/employers/63198',
#     'alternate_url': 'https://hh.ru/employer/63198',
#     'logo_urls': {'90': 'https://hhcdn.ru/employer-logo/323914.png',
#      '240': 'https://hhcdn.ru/employer-logo/396771.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/217795.gif'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=63198',
#     'trusted': True},
#    'snippet': {'requirement': 'Базовое знакомство с <highlighttext>Java</highlighttext> SE (от 6 месяцев изучения). Знание основ ООП. Знакомство с принципами тестирования ПО. Знание английского языка...',
#     'responsibility': 'Разработка и сопровождение решений на базе <highlighttext>Java</highlighttext>-платформы. Поддержка и консультация пользователей программного продукта. Анализ требований пользователей и постановка задач.'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '45321089',
#    'premium': False,
#    'name': 'Java-разработчик (Senior)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 260000, 'to': 350000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-06-12T02:05:21+0300',
#    'created_at': '2021-06-12T02:05:21+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=45321089',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/45321089?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/45321089',
#    'relations': [],
#    'employer': {'id': '2933713',
#     'name': 'ZeroHub',
#     'url': 'https://api.hh.ru/employers/2933713',
#     'alternate_url': 'https://hh.ru/employer/2933713',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3101237.png',
#      '90': 'https://hhcdn.ru/employer-logo/3101236.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/665026.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2933713',
#     'trusted': True},
#    'snippet': {'requirement': 'Активная разработка на серверном <highlighttext>Java</highlighttext> в течение последних 3-4 лет. Знание фреймворка Spring. Умение писать чистый и понятный код. ',
#     'responsibility': None},
#    'contacts': None,
#    'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '44672425',
#    'premium': False,
#    'name': 'Java разработчик (удаленно)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '2',
#     'name': 'Санкт-Петербург',
#     'url': 'https://api.hh.ru/areas/2'},
#    'salary': {'from': 3000, 'to': 4000, 'currency': 'USD', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-06-11T12:25:34+0300',
#    'created_at': '2021-06-11T12:25:34+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=44672425',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/44672425?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/44672425',
#    'relations': [],
#    'employer': {'id': '1035859',
#     'name': 'SimpleTexting',
#     'url': 'https://api.hh.ru/employers/1035859',
#     'alternate_url': 'https://hh.ru/employer/1035859',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/526637.png',
#      '240': 'https://hhcdn.ru/employer-logo/2548026.png',
#      '90': 'https://hhcdn.ru/employer-logo/2548025.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1035859',
#     'trusted': True},
#    'snippet': {'requirement': 'Высшее техническое образование и 4+ лет опыт коммерческой разработки на <highlighttext>Java</highlighttext>. Большим плюсом будет опыт работы с MongoDB. ',
#     'responsibility': 'Для работы достаточно технического английского, общение в команде разработки идет на русском языке.'},
#    'contacts': None,
#    'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '44646310',
#    'premium': False,
#    'name': 'Стажер Java-разработчик',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '78', 'name': 'Самара', 'url': 'https://api.hh.ru/areas/78'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Самара',
#     'street': 'Московское шоссе',
#     'building': '55',
#     'description': None,
#     'lat': 53.224271,
#     'lng': 50.192801,
#     'raw': 'Самара, Московское шоссе, 55',
#     'metro': None,
#     'metro_stations': [],
#     'id': '980179'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-06-10T16:03:51+0300',
#    'created_at': '2021-06-10T16:03:51+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=44646310',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/44646310?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/44646310',
#    'relations': [],
#    'employer': {'id': '2814484',
#     'name': 'LinkAge',
#     'url': 'https://api.hh.ru/employers/2814484',
#     'alternate_url': 'https://hh.ru/employer/2814484',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/670627.JPG',
#      '240': 'https://hhcdn.ru/employer-logo/3123641.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3123640.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2814484',
#     'trusted': True},
#    'snippet': {'requirement': 'Обучаемость, инженерное мышление, позитивный настрой и упорство в достижении цели. Опыт программирования на <highlighttext>Java</highlighttext>. Знание Английского языка на уровне Intermediate...',
#     'responsibility': 'Промежуточные тестирования.'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [{'id': 'from_four_to_six_hours_in_a_day',
#      'name': 'Можно работать сменами по\xa04–6 часов в\xa0день'}],
#    'working_time_modes': [{'id': 'start_after_sixteen',
#      'name': 'Можно начинать работать после 16:00'}],
#    'accept_temporary': False},
#   {'id': '45369709',
#    'premium': False,
#    'name': 'Java Developer (Junior)',
#    'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-06-10T12:00:40+0300',
#    'created_at': '2021-06-10T12:00:40+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=45369709',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/45369709?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/45369709',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'Сбербанк',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/853994.jpg',
#      '240': 'https://hhcdn.ru/employer-logo/3856852.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3856851.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Понимание принципов ООП, методологий разработки, шаблонов проектирования. Знание <highlighttext>Java</highlighttext> (не ниже 8 версии). Spring Boot. JDBC, Hibernate. SQL. Git. Maven.',
#     'responsibility': 'Проектирование сервисов и их реализация. Разработка функциональности согласно поставленной задаче. Оптимизация функциональности системы. Диагностирование и исправление ошибок. Проведение ревью кода.'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '45371319',
#    'premium': False,
#    'name': 'Senior Java Developer',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '2',
#     'name': 'Санкт-Петербург',
#     'url': 'https://api.hh.ru/areas/2'},
#    'salary': {'from': 3000, 'to': 4000, 'currency': 'USD', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-06-10T12:35:30+0300',
#    'created_at': '2021-06-10T12:35:30+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=45371319',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/45371319?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/45371319',
#    'relations': [],
#    'employer': {'id': '5473019',
#     'name': 'The Neuron',
#     'url': 'https://api.hh.ru/employers/5473019',
#     'alternate_url': 'https://hh.ru/employer/5473019',
#     'logo_urls': None,
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=5473019',
#     'trusted': False},
#    'snippet': {'requirement': 'Устный и письменный английский (хотя бы минимальный уровень). Опыт коммерческой разработки на <highlighttext>Java</highlighttext> от 3х лет. Опыт использования Spring...',
#     'responsibility': None},
#    'contacts': None,
#    'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '45150706',
#    'premium': False,
#    'name': 'Android-разработчик',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 225000, 'to': 300000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': None,
#     'building': None,
#     'description': None,
#     'lat': 55.77435,
#     'lng': 37.653846,
#     'raw': 'Москва',
#     'metro': {'station_name': 'Комсомольская',
#      'line_name': 'Кольцевая',
#      'station_id': '5.55',
#      'line_id': '5',
#      'lat': 55.775672,
#      'lng': 37.654772},
#     'metro_stations': [{'station_name': 'Комсомольская',
#       'line_name': 'Кольцевая',
#       'station_id': '5.55',
#       'line_id': '5',
#       'lat': 55.775672,
#       'lng': 37.654772}],
#     'id': '3017431'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-06-11T14:23:47+0300',
#    'created_at': '2021-06-11T14:23:47+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=45150706',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/45150706?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/45150706',
#    'relations': [],
#    'employer': {'id': '2905287',
#     'name': 'Овертим',
#     'url': 'https://api.hh.ru/employers/2905287',
#     'alternate_url': 'https://hh.ru/employer/2905287',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/679752.png',
#      '240': 'https://hhcdn.ru/employer-logo/3160141.png',
#      '90': 'https://hhcdn.ru/employer-logo/3160140.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2905287',
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт: Знание <highlighttext>Java</highlighttext>/Kotlin. Опыт коммерческой разработки Android-приложений не менее двух лет. Опыт параллельного и многопоточного программирования. ',
#     'responsibility': 'Мобильное приложение для корпоративного клиента для оказания телемедицинских консультаций, в рамках которого реализован функционал записи ко врачу на прием, получение...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '42798174',
#    'premium': False,
#    'name': 'Стажер-разработчик Java',
#    'department': {'id': '733-733-bpm', 'name': 'ЛАНИТ - Би Пи Эм'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 30000, 'to': None, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Мурманский проезд',
#     'building': '14к1',
#     'description': None,
#     'lat': 55.807015,
#     'lng': 37.622315,
#     'raw': 'Москва, Мурманский проезд, 14к1',
#     'metro': {'station_name': 'Алексеевская',
#      'line_name': 'Калужско-Рижская',
#      'station_id': '6.8',
#      'line_id': '6',
#      'lat': 55.807794,
#      'lng': 37.638699},
#     'metro_stations': [{'station_name': 'Алексеевская',
#       'line_name': 'Калужско-Рижская',
#       'station_id': '6.8',
#       'line_id': '6',
#       'lat': 55.807794,
#       'lng': 37.638699},
#      {'station_name': 'Марьина Роща',
#       'line_name': 'Люблинско-Дмитровская',
#       'station_id': '10.185',
#       'line_id': '10',
#       'lat': 55.793723,
#       'lng': 37.61618},
#      {'station_name': 'Рижская',
#       'line_name': 'Калужско-Рижская',
#       'station_id': '6.126',
#       'line_id': '6',
#       'lat': 55.792494,
#       'lng': 37.636114}],
#     'id': '385530'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-06-10T17:38:28+0300',
#    'created_at': '2021-06-10T17:38:28+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=42798174',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/42798174?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/42798174',
#    'relations': [],
#    'employer': {'id': '733',
#     'name': 'ЛАНИТ',
#     'url': 'https://api.hh.ru/employers/733',
#     'alternate_url': 'https://hh.ru/employer/733',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/2627354.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/2627353.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/546470.jpg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=733',
#     'trusted': True},
#    'snippet': {'requirement': 'Высшее техническое образование или старшие курсы университета. Знание основ языка программирования: <highlighttext>Java</highlighttext>. Написание простых sql запросов. Владение английским языком на...',
#     'responsibility': 'Познакомиться с лучшими практиками разработки ПО, DevOps, Code review. Участвовать в масштабных проектах по автоматизации и оптимизации бизнес-процессов.'},
#    'contacts': None,
#    'schedule': {'id': 'flexible', 'name': 'Гибкий график'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '45373944',
#    'premium': False,
#    'name': 'Программист Java/Kotlin (бэкэнд) Без опыта/Junior/Middle',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '107',
#     'name': 'Чебоксары',
#     'url': 'https://api.hh.ru/areas/107'},
#    'salary': {'from': 30000, 'to': 140000, 'currency': 'RUR', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Чебоксары',
#     'street': 'улица Афанасьева',
#     'building': '9к2',
#     'description': None,
#     'lat': 56.148874,
#     'lng': 47.214517,
#     'raw': 'Чебоксары, улица Афанасьева, 9к2',
#     'metro': None,
#     'metro_stations': [],
#     'id': '4510895'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-06-10T13:34:28+0300',
#    'created_at': '2021-06-10T13:34:28+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=45373944',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/45373944?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/45373944',
#    'relations': [],
#    'employer': {'id': '1113815',
#     'name': 'eRaga Infosystem',
#     'url': 'https://api.hh.ru/employers/1113815',
#     'alternate_url': 'https://hh.ru/employer/1113815',
#     'logo_urls': {'90': 'https://hhcdn.ru/employer-logo/1530998.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/272117.png',
#      '240': 'https://hhcdn.ru/employer-logo/1530999.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1113815',
#     'trusted': True},
#    'snippet': {'requirement': 'Знание особенностей работы компиляторов (например, GCC, LLVM, Clang) и трансляторов (PHP, <highlighttext>Java</highlighttext>, .NET, Mono). Знакомство с любой IDE JetBrainsIDEA. ',
#     'responsibility': None},
#    'contacts': None,
#    'schedule': {'id': 'flexible', 'name': 'Гибкий график'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': True},
#   {'id': '43018148',
#    'premium': False,
#    'name': 'Java разработчик',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 170000, 'to': 250000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'улица Ленинская Слобода',
#     'building': '19с2',
#     'description': None,
#     'lat': 55.708075,
#     'lng': 37.655176,
#     'raw': 'Москва, улица Ленинская Слобода, 19с2',
#     'metro': {'station_name': 'Автозаводская',
#      'line_name': 'Замоскворецкая',
#      'station_id': '2.2',
#      'line_id': '2',
#      'lat': 55.706634,
#      'lng': 37.657008},
#     'metro_stations': [{'station_name': 'Автозаводская',
#       'line_name': 'Замоскворецкая',
#       'station_id': '2.2',
#       'line_id': '2',
#       'lat': 55.706634,
#       'lng': 37.657008}],
#     'id': '2056562'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-06-10T20:59:04+0300',
#    'created_at': '2021-06-10T20:59:04+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=43018148',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/43018148?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/43018148',
#    'relations': [],
#    'employer': {'id': '208576',
#     'name': 'МойСклад',
#     'url': 'https://api.hh.ru/employers/208576',
#     'alternate_url': 'https://hh.ru/employer/208576',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/608665.png',
#      '240': 'https://hhcdn.ru/employer-logo/2875813.png',
#      '90': 'https://hhcdn.ru/employer-logo/2875812.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=208576',
#     'trusted': True},
#    'snippet': {'requirement': 'Пишет на <highlighttext>Java</highlighttext> уже пару лет. Уверенно знает алгоритмы и структуры данных. Хорошо знает реляционные БД и SQL. ',
#     'responsibility': 'Займетесь реализацией серверных компонентов (стек технологий: <highlighttext>Java</highlighttext> 8 → 11, WildFly, EJB/немного Spring, Kafka, Hibernate, PostgreSQL). Будете разрабатывать клиентскую часть...'},
#    'contacts': None,
#    'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '45409469',
#    'premium': False,
#    'name': 'Junior Java developer',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Шарикоподшипниковская улица',
#     'building': '4',
#     'description': None,
#     'lat': 55.720849,
#     'lng': 37.672459,
#     'raw': 'Москва, Шарикоподшипниковская улица, 4',
#     'metro': {'station_name': 'Дубровка',
#      'line_name': 'Люблинско-Дмитровская',
#      'station_id': '10.39',
#      'line_id': '10',
#      'lat': 55.71807,
#      'lng': 37.676259},
#     'metro_stations': [{'station_name': 'Дубровка',
#       'line_name': 'Люблинско-Дмитровская',
#       'station_id': '10.39',
#       'line_id': '10',
#       'lat': 55.71807,
#       'lng': 37.676259}],
#     'id': '120416'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-06-11T15:10:54+0300',
#    'created_at': '2021-06-11T15:10:54+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=45409469',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/45409469?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/45409469',
#    'relations': [],
#    'employer': {'id': '900721',
#     'name': 'ГСПИ',
#     'url': 'https://api.hh.ru/employers/900721',
#     'alternate_url': 'https://hh.ru/employer/900721',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/766123.png',
#      '90': 'https://hhcdn.ru/employer-logo/3505449.png',
#      '240': 'https://hhcdn.ru/employer-logo/3505450.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=900721',
#     'trusted': True},
#    'snippet': {'requirement': 'Знание web-технологий. Опыт коммерческой разработки на <highlighttext>Java</highlighttext> от полугода. Знание <highlighttext>JAVA</highlighttext> 11, <highlighttext>JAVA</highlighttext> EE. Умение разбираться в чужом коде. ',
#     'responsibility': 'Обеспечение работоспособности информационных систем класса PLM/PDM: исправление ошибок, сопровождение обновлений и доработка систем по поставленным задачам от бизнес аналитиков...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '45369037',
#    'premium': False,
#    'name': 'Java developer (Стажер)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1002',
#     'name': 'Минск',
#     'url': 'https://api.hh.ru/areas/1002'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Минск',
#     'street': 'улица Платонова',
#     'building': '43',
#     'description': None,
#     'lat': 53.912378,
#     'lng': 27.597701,
#     'raw': 'Минск, улица Платонова, 43',
#     'metro': {'station_name': 'Площадь Якуба Коласа',
#      'line_name': 'Московская',
#      'station_id': '62.408',
#      'line_id': '62',
#      'lat': 53.915369,
#      'lng': 27.583265},
#     'metro_stations': [{'station_name': 'Площадь Якуба Коласа',
#       'line_name': 'Московская',
#       'station_id': '62.408',
#       'line_id': '62',
#       'lat': 53.915369,
#       'lng': 27.583265}],
#     'id': '229343'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-06-10T11:49:18+0300',
#    'created_at': '2021-06-10T11:49:18+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=45369037',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/45369037?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/45369037',
#    'relations': [],
#    'employer': {'id': '1011638',
#     'name': 'JazzTeam',
#     'url': 'https://api.hh.ru/employers/1011638',
#     'alternate_url': 'https://hh.ru/employer/1011638',
#     'logo_urls': {'90': 'https://hhcdn.ru/employer-logo/684572.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/684573.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/94949.jpg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1011638',
#     'trusted': True},
#    'snippet': {'requirement': 'Владение основным стеком Web разработки (Spring, Hibernate, JavaScript/AJAX, jQuery (знание Angular JS - плюс), знание спецификации <highlighttext>Java</highlighttext> Servlets, хороший уровень...',
#     'responsibility': 'Разработка программного обеспечения с использованием технологии <highlighttext>Java</highlighttext>. Участие в Agile/Scrum/XP процессах компании в качестве участника Scrum команды. '},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '44956402',
#    'premium': False,
#    'name': 'Java-разработчик (Junior)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1550',
#     'name': 'Таганрог',
#     'url': 'https://api.hh.ru/areas/1550'},
#    'salary': {'from': 50000, 'to': 70000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Таганрог',
#     'street': 'Шаумяна',
#     'building': '19',
#     'description': None,
#     'lat': 47.265279,
#     'lng': 38.930415,
#     'raw': 'Таганрог, Шаумяна, 19',
#     'metro': None,
#     'metro_stations': [],
#     'id': '98872'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-06-11T17:52:59+0300',
#    'created_at': '2021-06-11T17:52:59+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=44956402',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/44956402?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/44956402',
#    'relations': [],
#    'employer': {'id': '829378',
#     'name': 'Комплексные программные решения',
#     'url': 'https://api.hh.ru/employers/829378',
#     'alternate_url': 'https://hh.ru/employer/829378',
#     'logo_urls': None,
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=829378',
#     'trusted': True},
#    'snippet': {'requirement': 'Знания <highlighttext>Java</highlighttext> Core (SE). Знание классических алгоритмов и структур данных. Опыт работы с SVN/GIT. Ожидания от кандидата: Желание получить...',
#     'responsibility': 'Совершенствоваться и участвовать в разработке распределенных многомодульных информационных систем, используя технологии: Сервером приложений Tomcat.'},
#    'contacts': None,
#    'schedule': {'id': 'flexible', 'name': 'Гибкий график'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '42450240',
#    'premium': False,
#    'name': 'Java Team Lead (Content)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 300000, 'to': None, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Новослободская улица',
#     'building': '16',
#     'description': None,
#     'lat': 55.781701,
#     'lng': 37.599364,
#     'raw': 'Москва, Новослободская улица, 16',
#     'metro': {'station_name': 'Менделеевская',
#      'line_name': 'Серпуховско-Тимирязевская',
#      'station_id': '9.83',
#      'line_id': '9',
#      'lat': 55.781999,
#      'lng': 37.599141},
#     'metro_stations': [{'station_name': 'Менделеевская',
#       'line_name': 'Серпуховско-Тимирязевская',
#       'station_id': '9.83',
#       'line_id': '9',
#       'lat': 55.781999,
#       'lng': 37.599141},
#      {'station_name': 'Новослободская',
#       'line_name': 'Кольцевая',
#       'station_id': '5.82',
#       'line_id': '5',
#       'lat': 55.779606,
#       'lng': 37.601252}],
#     'id': '5896955'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-06-11T07:40:47+0300',
#    'created_at': '2021-06-11T07:40:47+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=42450240',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/42450240?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/42450240',
#    'relations': [],
#    'employer': {'id': '3297595',
#     'name': 'Prequel',
#     'url': 'https://api.hh.ru/employers/3297595',
#     'alternate_url': 'https://hh.ru/employer/3297595',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/662133.jpg',
#      '240': 'https://hhcdn.ru/employer-logo/3089665.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/3089664.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3297595',
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт управления командой 3-5 человек от 2 лет. Опыт выстраивания командных процессов, сейчас команда работает по скраму. ',
#     'responsibility': 'Развивать <highlighttext>Java</highlighttext> (Kotlin) направление в компании. Собирать требования, проектировать и управлять реализацией продуктовых (и немного технических) проектов. Взаимодействовать с продуктами...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '45411208',
#    'premium': False,
#    'name': 'Java Script developer (стажер)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': True,
#    'area': {'id': '1002',
#     'name': 'Минск',
#     'url': 'https://api.hh.ru/areas/1002'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Минск',
#     'street': 'улица Академика Купревича',
#     'building': '1к5',
#     'description': None,
#     'lat': 53.927703,
#     'lng': 27.68119,
#     'raw': 'Минск, улица Академика Купревича, 1к5',
#     'metro': None,
#     'metro_stations': [],
#     'id': '741692'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-06-11T15:46:44+0300',
#    'created_at': '2021-06-11T15:46:44+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=45411208',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/45411208?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/45411208',
#    'relations': [],
#    'employer': {'id': '2645886',
#     'name': 'Дуал Лаб Бел',
#     'url': 'https://api.hh.ru/employers/2645886',
#     'alternate_url': 'https://hh.ru/employer/2645886',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/379979.png',
#      '90': 'https://hhcdn.ru/employer-logo/1962174.png',
#      '240': 'https://hhcdn.ru/employer-logo/1962175.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2645886',
#     'trusted': True},
#    'snippet': {'requirement': 'Получение новых теоретических знаний и применение их на практике. Понимание принципов ООП. Знание основ веб-разработки. HTML / CSS / JavaScript. ',
#     'responsibility': 'Изучение инструментов и процессов командной разработки.'},
#    'contacts': None,
#    'schedule': {'id': 'flexible', 'name': 'Гибкий график'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '45132705',
#    'premium': False,
#    'name': 'Java Developer',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '4',
#     'name': 'Новосибирск',
#     'url': 'https://api.hh.ru/areas/4'},
#    'salary': {'from': 2500, 'to': 3500, 'currency': 'USD', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-06-11T08:40:27+0300',
#    'created_at': '2021-06-11T08:40:27+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=45132705',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/45132705?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/45132705',
#    'relations': [],
#    'employer': {'id': '1101806',
#     'name': 'Brmsystems.com',
#     'url': 'https://api.hh.ru/employers/1101806',
#     'alternate_url': 'https://hh.ru/employer/1101806',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/2632442.png',
#      '90': 'https://hhcdn.ru/employer-logo/2632441.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/547742.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1101806',
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт работы с микросервисной архитектурой. Опыт работы с <highlighttext>Java</highlighttext> 8 и выше. Умение готовить SpringBoot. Умение работать и без Spring. ',
#     'responsibility': None},
#    'contacts': None,
#    'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': True},
#   {'id': '44564302',
#    'premium': False,
#    'name': 'Java-разработчик',
#    'department': None,
#    'has_test': True,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 225000, 'to': 375000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-06-12T16:04:10+0300',
#    'created_at': '2021-06-12T16:04:10+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=44564302',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/44564302?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/44564302',
#    'relations': [],
#    'employer': {'id': '3140842',
#     'name': 'Шпак Виктория Сергеевна',
#     'url': 'https://api.hh.ru/employers/3140842',
#     'alternate_url': 'https://hh.ru/employer/3140842',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/772947.jpg',
#      '90': 'https://hhcdn.ru/employer-logo/3532679.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3532680.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3140842',
#     'trusted': True},
#    'snippet': {'requirement': '...знания <highlighttext>Java</highlighttext> и опыт коммерческой разработки - от 4-х лет. - Хорошее понимание веб-технологий и опыт разработки бэкенда на <highlighttext>Java</highlighttext>. - ',
#     'responsibility': None},
#    'contacts': None,
#    'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': True}],
#  'found': 11647,
#  'pages': 100,
#  'per_page': 20,
#  'page': 0,
#  'clusters': None,
#  'arguments': None,
#  'alternate_url': 'https://hh.ru/search/vacancy?enable_snippets=true&text=java'}

# %% [markdown]
# # Собираем данные по специальности

# %%
 
def getPage(page = 0):
    params = {
        'text': 'NAME:Аналитик', # Текст фильтра. В имени должно быть слово "Аналитик"
        'area': 1, # Поиск ощуществляется по вакансиям города Москва
        'page': page, # Индекс страницы поиска на HH
        'per_page': 100 # Кол-во вакансий на 1 странице
    }
     
    req = requests.get('https://api.hh.ru/vacancies', params) # Посылаем запрос к API
    data = req.content.decode() # Декодируем его ответ, чтобы Кириллица отображалась корректно
    req.close()
    return data
 
for page in range(0, 20):
    jsObj = json.loads(getPage(page))
    nextFileName = './docs/pagination/{}.json'.format(len(os.listdir('./docs/pagination')))
    f = open(nextFileName, mode='w', encoding='utf8')
    f.write(json.dumps(jsObj, ensure_ascii=False))
    f.close()
    if (jsObj['pages'] - page) <= 1:
        break
     
    # Необязательная задержка, но чтобы не нагружать сервисы hh, оставим. 5 сек мы может подождать
    time.sleep(0.25)
     
print('Старницы поиска собраны')
# Out:
# Старницы поиска собраны

# %% [markdown]
# # Собираем данные по вакансии

# %%
 
# Получаем перечень ранее созданных файлов со списком вакансий и проходимся по нему в цикле 
for fl in os.listdir('./docs/pagination'):
     
    # Открываем файл, читаем его содержимое, закрываем файл
    f = open('./docs/pagination/{}'.format(fl), encoding='utf8')
    jsonText = f.read()
    f.close()
     
    # Преобразуем полученный текст в объект справочника
    jsonObj = json.loads(jsonText)
     
    # Получаем и проходимся по непосредственно списку вакансий
    for v in jsonObj['items']:
         
        # Обращаемся к API и получаем детальную информацию по конкретной вакансии
        req = requests.get(v['url'])
        data = req.content.decode()
        req.close()
         
        # Создаем файл в формате json с идентификатором вакансии в качестве названия
        # Записываем в него ответ запроса и закрываем файл
        fileName = './docs/vacancies/{}.json'.format(v['id'])
        f = open(fileName, mode='w', encoding='utf8')
        f.write(data)
        f.close()
         
        time.sleep(0.25)
         
print('Вакансии собраны')
# Out:
# Вакансии собраны

# %% [markdown]
# # Собираем данные в  базу данных

# %%
 
# Создаем списки для столбцов таблицы vacancies
IDs = [] # Список идентификаторов вакансий
names = [] # Список наименований вакансий
descriptions = [] # Список описаний вакансий
 
# Создаем списки для столбцов таблицы skills
skills_vac = [] # Список идентификаторов вакансий
skills_name = [] # Список названий навыков
 
# В выводе будем отображать прогресс
# Для этого узнаем общее количество файлов, которые надо обработать
# Счетчик обработанных файлов установим в ноль
cnt_docs = len(os.listdir('./docs/vacancies'))
i = 0
 
# Проходимся по всем файлам в папке vacancies
for fl in os.listdir('./docs/vacancies'):
     
    # Открываем, читаем и закрываем файл
    f = open('./docs/vacancies/{}'.format(fl), encoding='utf8')
    jsonText = f.read()
    f.close()
     
    # Текст файла переводим в справочник
    jsonObj = json.loads(jsonText)
     
    # Заполняем списки для таблиц
    IDs.append(jsonObj['id'])
    names.append(jsonObj['name'])
    descriptions.append(jsonObj['description'])
     
    # Т.к. навыки хранятся в виде массива, то проходимся по нему циклом
    for skl in jsonObj['key_skills']:
        skills_vac.append(jsonObj['id'])
        skills_name.append(skl['name'])
     
    # Увеличиваем счетчик обработанных файлов на 1, очищаем вывод ячейки и выводим прогресс
    i += 1
    display.clear_output(wait=True)
    display.display('Готово {} из {}'.format(i, cnt_docs))
 
 
# Создадим соединение с БД
eng = sql.create_engine('localdatabase')
conn = eng.connect()
 
# Создаем пандосовский датафрейм, который затем сохраняем в БД в таблицу vacancies
df = pd.DataFrame({'id': IDs, 'name': names, 'description': descriptions})
df.to_sql('vacancies', conn, schema='public', if_exists='append', index=False)
 
# Тоже самое, но для таблицы skills
df = pd.DataFrame({'vacancy': skills_vac, 'skill': skills_name})
df.to_sql('skills', conn, schema='public', if_exists='append', index=False)
 
# Закрываем соединение с БД
conn.close()
 
# Выводим сообщение об окончании программы
display.clear_output(wait=True)
display.display('Вакансии загружены в БД')
# Out:
# 'Вакансии загружены в БД'

# %% [markdown]
# # Создаем облако вакансий из токенов

# %%
conn = sqlalchemy.create_engine('localdatabase').connect()
sql = 'select name from public.vacancies'
vacancies_name = pd.read_sql(sql, conn).name
sql = "select v.name,skill from public.skills s join public.vacancies v on v.id = s.vacancy"
skills = pd.read_sql(sql, conn)

conn.close()

from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer

cv=CountVectorizer(ngram_range=(2,2),stop_words=['ведущий', 'главный', 'младший', 'эксперт', 'стажер', 'старший', 'middle', 'junior', 'senior'],min_df=0.001)
word_vector=cv.fit_transform(vacancies_name)

idf = TfidfTransformer().fit(word_vector)

df_idf = pd.DataFrame(idf.idf_, index=cv.get_feature_names(), columns=["idf"])

pivot = pd.DataFrame(word_vector.toarray(), columns=cv.get_feature_names(), index=vacancies_name.values)

# %%
# Импортируем виджеты. Они позволяют более гибко управлять выводом jupyter и 
# создавать интерактивные элементы
import ipywidgets as widget
 
# Импортируем модуль вывода jupyter
from IPython import display
 
# Библиотека для визуализации данных
import matplotlib.pyplot as plt
 
# Модуль математических функций
import math
 
################################################
 
def click_back(b):
    """
       Метод, который вызывается при клике на кнопку "Назад".
       Метод скрывает информацию о перечне вакансий из левого сайдбара и
       диаграмму популярности навыков из правого сайдбара, а также отображает
       в центральной части шаблона облако токенов.
    """
    app_layout.left_sidebar = None
    app_layout.right_sidebar = None
    app_layout.center = out_words
 
################################################
 
def print_words(x):
    """
        Метод, который вызывается при изменении значения слайдера.
        Метод отрисовывает в формате html облако токенов
         
        Аргумент "x" принимает справочник, который содержит состояние слайдера. Используем
        x.new, чтобы получить новое состояние слайдера.
    """
     
    # Получаем датафрейм, отсортированный в обратном порядке по мере idf, 
    # ограниченный диапазоном значений, заданным слайдером
    ds = df_idf.sort_values(by='idf', ascending=False)[x.new[0]: x.new[1]]
     
    # Получаем максимальное и минимальное значения idf. Будем использовать их для установки
    # размера шрифта токена в облаке
    mx = df_idf['idf'].max()
    mn = df_idf['idf'].min()
     
    # Задаем общие css-стили для облака токенов
    tags = """<style>
    .tagword{
        border:1px solid #bee5eb;
        padding:1px 5px;
        display:block;
        border-radius:4px;
        color:#0c5460;
        background:#d1ecf1;
        line-height:normal;
        cursor:pointer}
    .tagword:hover{
        background:#c1dce1}
    .tag-wrapper{
        float:left;
        margin:0 5px 5px 0}
    </style>"""
     
    # Пробегаемся по токенам, выбранным с помощью слайдера
    for r in ds.sort_index().itertuples():
         
        # Масштабируем значения idf от 0 до 1 и переворачиваем их, 
        # чтобы максимальное значение стало минимальным.
        if mx > mn:
             
            # Задаем размер шрифта и высоту токена в облаке
            fs = int( (((r.idf - mn) / (mx - mn)) * -1 + 1 ) * 30 + 10 )
            hd = math.ceil(fs / 10) * 10 + 8
        else:
            fs = 40
         
        # Добавляем токен в облако в формате html. Токену назначаем функцию tag_click для
        # события клика. Сама функция описана ниже за пределами данного метода
        tag_tmpl = """<div class="tag-wrapper" style="height:{height}px">
            <span onclick="tag_click(this)" class="tagword" style="font-size:{size}px">{name}</span>
        </div>"""
        tags += tag_tmpl.format(name=r.Index, size=fs, height=hd)
     
    # Отрисовываем облако токенов 
    click_back(None)
    out_words.clear_output(wait=True)
    with out_words:
        display.display_html(tags, raw=True)
         
################################################
         
def get_detail(w):
    """
        Метод отрисовывает детелизацию по токену, а именно перечень вакансий, 
        содержащих переданный токен, и топ-20 самых востребованных навыков по этим вакансиям.
         
        Аргумент "w" принимает значение токена, по которому кликнули
    """
     
    # Выводим пандосовский датафрейм со списком вакансий, содержащих токен
    out_details_vac.clear_output(wait=True)
    vacs = pivot[pivot[w] > 0].sort_index().index.unique()
    with out_details_vac:
        display.display_html(
                pd.DataFrame(data=vacs, columns=['Список вакансий:']).to_html(index=False), raw=True
        )
     
    # Выводим горизонтальный столбчатый график самых популярных навыков по выбранным вакансиям
    out_details_skl.clear_output(wait=True)
    skill_pvt = skills \
                .query('name in @vacs') \
                .groupby(by='skill', as_index=False) \
                .agg({'name':'count'}) \
                .sort_values(by='name', ascending=False).head(20)
    fig_h = skill_pvt.shape[0] / 2.5    # Корректируем размер графика на 
                                        # основании количества получившихся столбцов
    with out_details_skl:
        skill_pvt.sort_values(by='name').plot.barh(
                        x='skill', 
                        y='name', 
                        figsize=(5, fig_h), 
                        legend=None, 
                        title='ТОП20 Навыков'
        )
        plt.show()
     
     
    # Скрываем облако токенов и выводим детализацию для токена
    app_layout.center = None
    app_layout.left_sidebar = out_details_vac
    app_layout.right_sidebar = out_details_skl
 
################################################
 
# Создаем несколько виджетов вывода
out_header = widget.Output() # Сюда будем выводить виджет слайдера и кнопку возврата
out_words = widget.Output() # Сюда будем выводить облако
out_details_vac = widget.Output() # Сюда будем выводить перечень вакансий, содержащих токен
out_details_skl = widget.Output() # Сюда будем выводить график навыков по вакансиям, содержащим токен
 
# Создаем виджет макета. Весь отчет по сути располагается в данном макете.
# Пока только с выводом в центр виджета с облаком
app_layout = widget.AppLayout(
    header=None,
    left_sidebar=None,
    center=out_words,
    right_sidebar=None,
    footer=None,
    pane_heights=[1, 5, '60px']
)
 
# Создаем виджет слайдера, для указания диапазона рассматриваемых токенов
sld = widget.IntRangeSlider(
    value=[0, 0],
    min=0,
    max=df_idf['idf'].count(),
    step=1,
    description='Частота:',
    layout = {'width': '100%'}
)
# Назначаем слайдеру метод, который будет вызываться при изменении значения слайдера
sld.observe(print_words, names='value')
 
# Создаем виджет кнопки
bck_btn = widget.Button(
    description='Назад',
    button_style='info'
)
# Назначаем кнопке метод, который будет вызываться по событию клика по ней
bck_btn.on_click(click_back)
 
# В формате html подготовим строку, которая создаст функцию на языке javascript
# Данную функцию будем вызывать по событию клика по токену в облаке
html = """
<script>
    function tag_click(e){
        var kernel = Jupyter.notebook.kernel
        func = 'get_detail("' + e.innerText + '")'
        kernel.execute(func)
    }
</script>"""
 
# Выводим в виджет вывода виджеты слайдера и кнопки
with out_header:
    display.display(sld)
    display.display(bck_btn)
 
display.display_html(html, raw=True) # Отображаем в ячейке ранее подготовленный html c js-функцией
display.display(out_header) # Отображаем виджет, содержащий слайдер и кнопку
display.display(app_layout) # Отображаем виджет макета
 
# Задаем новые значения диапазона слайдера, чтобы отобразить ТОП-30 самых популярных токенов
# Данная строка спровоцирует изменения, что в свою очередь вызовет установленный метод print_words,
# который формирует облако
sld.value = [sld.max - 30, sld.max]
# Out:
# <script>
#     function tag_click(e){
#         var kernel = Jupyter.notebook.kernel
#         func = 'get_detail("' + e.innerText + '")'
#         kernel.execute(func)
#     }
# </script>
# Output()
# AppLayout(children=(Output(layout=Layout(grid_area='center')),), layout=Layout(grid_template_areas='"center ce…
